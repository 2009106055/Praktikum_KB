# %% [markdown]
# <h1>POSTTEST 4</h1>
# <p>Muhammad Alfarezy Cannavaro</p>
# <a href='https://github.com/2009106055/Praktikum_KB'>Link Github Alfarezy</a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

#Untuk Melakukan Data Split
from sklearn.model_selection import train_test_split
#Untuk Melakukan Data Transforming
from sklearn.preprocessing import StandardScaler #standarisasi
from sklearn.preprocessing import MinMaxScaler #normalisasi
#Untuk Melakukan Data Cleaning
from sklearn.impute import SimpleImputer
#Untuk Melakukan Data Encoding
from sklearn.preprocessing import OrdinalEncoder #encoder
from sklearn.preprocessing import OneHotEncoder #onehot

# %%
df = pd.read_csv("tmdb_5000_movies.csv")

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
df2 = pd.read_csv('database.csv')

# %%
df2
# Out:
#            Year  Ceremony                             Award  Winner  \
# 0     1927/1928         1                             Actor     NaN
# 1     1927/1928         1                             Actor     1.0
# 2     1927/1928         1                           Actress     NaN
# 3     1927/1928         1                           Actress     1.0
# 4     1927/1928         1                           Actress     NaN
# ...         ...       ...                               ...     ...
# 9959       2015        88     Writing (Original Screenplay)     1.0
# 9960       2015        88     Writing (Original Screenplay)     NaN
# 9961       2015        88  Jean Hersholt Humanitarian Award     1.0
# 9962       2015        88                    Honorary Award     1.0
# 9963       2015        88                    Honorary Award     1.0
#
#                         Name  \
# 0        Richard Barthelmess
# 1              Emil Jannings
# 2             Louise Dresser
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9964 entries, 0 to 9963
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      9964 non-null   object
#  1   Ceremony  9964 non-null   int64
#  2   Award     9964 non-null   object
#  3   Winner    2321 non-null   float64
#  4   Name      9964 non-null   object
#  5   Film      9631 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 467.2+ KB

# %%
df2.isna().sum()
# Out:
# Year           0
# Ceremony       0
# Award          0
# Winner      7643
# Name           0
# Film         333
# dtype: int64

# %%
df3 = pd.read_csv('FIFA22_PlayerCards.csv')

# %%
df3
# Out:
#                PlayerName   Foot Position   AWR  DWR  OVR   PAC   SHO   PAS  \
# 0                    Pelé  Right      CAM  High  Med   98  95.0  96.0  93.0
# 1          Diego Maradona   Left      CAM  High  Med   97  92.0  93.0  92.0
# 2                 Ronaldo  Right       ST   Med  Med   96  97.0  95.0  81.0
# 3         Zinedine Zidane  Right      CAM   Med  Med   96  85.0  92.0  96.0
# 4          Diego Maradona   Left      CAM  High  Med   95  88.0  91.0  90.0
# ...                   ...    ...      ...   ...  ...  ...   ...   ...   ...
# 15923    Patrick McGarvey  Right       GK   Med  Med   48   NaN   NaN   NaN
# 15924  Lalbiakhlua Jongte   Left       GK   Med  Med   48   NaN   NaN   NaN
# 15925  Muheet Shabir Khan  Right       GK   Med  Med   48   NaN   NaN   NaN
# 15926         Arsh Shaikh  Right       GK   Med  Med   47   NaN   NaN   NaN
# 15927          Revanth By  Right       GK   Med  Med   47   NaN   NaN   NaN
#
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15928 entries, 0 to 15927
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   PlayerName  15928 non-null  object
#  1   Foot        15928 non-null  object
#  2   Position    15928 non-null  object
#  3   AWR         15919 non-null  object
#  4   DWR         15919 non-null  object
#  5   OVR         15928 non-null  int64
#  6   PAC         14162 non-null  float64
#  7   SHO         14162 non-null  float64
#  8   PAS         14162 non-null  float64
#  9   DRI         14162 non-null  float64
#  10  DEF         14162 non-null  float64
#  11  PHY         14162 non-null  float64
#  12  SM          15928 non-null  int64
#  13  DIV         1766 non-null   float64
#  14  POS         1766 non-null   float64
#  15  HAN         1766 non-null   float64
#  16  REF         1766 non-null   float64
#  17  KIC         1766 non-null   float64
# ...

# %%
df3.isna().sum()
# Out:
# PlayerName        0
# Foot              0
# Position          0
# AWR               9
# DWR               9
# OVR               0
# PAC            1766
# SHO            1766
# PAS            1766
# DRI            1766
# DEF            1766
# PHY            1766
# SM                0
# DIV           14162
# POS           14162
# HAN           14162
# REF           14162
# KIC           14162
# SPD           14162
# dtype: int64

# %% [markdown]
# <h1>DATA SPLIT</h1>

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.3)

# %%
print(f"Panjang X_train : {len(x_train)}",
      f"Panjang X_test : {len(x_test)}",
      f"Panjang y_train : {len(y_train)}",
      f"Panjang y_test : {len(y_test)}",
      sep='\n')
# Out:
# Panjang X_train : 3362
# Panjang X_test : 1441
# Panjang y_train : 3362
# Panjang y_test : 1441

# %% [markdown]
# <h1>DATA TRANSFORMING</h1>
# <p></p>

# %% [markdown]
# <h5>Normalisasi</h5>

# %%
normalisasi_dataset = df.copy()

# %%
scaler = MinMaxScaler()

normalize_dataset = scaler.fit_transform(normalisasi_dataset[['budget', 'runtime', 'popularity']])

normalize_dataset = pd.DataFrame(normalize_dataset)
normalize_dataset.rename(columns={0 :'budget', 1 :'runtime', 2 : 'popularity'}, inplace=True)

normalize_dataset.head(5)
# Out:
#      budget   runtime  popularity
# 0  0.623684  0.479290    0.171815
# 1  0.789474  0.500000    0.158846
# 2  0.644737  0.437870    0.122635
# 3  0.657895  0.488166    0.128272
# 4  0.684211  0.390533    0.050169

# %% [markdown]
# <h1>NOTES : MOHON MAAF BANG,DISINI UNTUK STANDARISASI NYA SAYA PINDAHKAN KE BAWAH DIKARENAKAN DATA SAYA MEMILIKI NILAI NULL DAN SAYA JADI MELAKUKAN CLEANING DATA TERLEBIH DAHULU DAN BAGIAN STANDARISASI NYA SUDAH SAYA PINDAHKAN KE BAWAH BANG </h1>

# %% [markdown]
# <h1>DATA CLEANING</h1>

# %%
dataset_cl1 = df.copy()
dataset_cl2 = df2.copy()
dataset_cl3 = df.copy()

# %%
imputer_mean = SimpleImputer(strategy='mean')
imputer_median = SimpleImputer(strategy='median')
imputer_modus = SimpleImputer(strategy='most_frequent')

# %% [markdown]
# <h5>Modus</h5>

# %%
dataset_cl1['runtime'] = imputer_modus.fit_transform(dataset_cl1[['runtime']])

dataset_mod.isna().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    0
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %% [markdown]
# <h5>Mean</h5>

# %%
dataset_cl2['Winner'] = imputer_mean.fit_transform(dataset_cl2[['Winner']])

dataset_cl2.isna().sum()
# Out:
# Year          0
# Ceremony      0
# Award         0
# Winner        0
# Name          0
# Film        333
# dtype: int64

# %% [markdown]
# <h5>Mengahpus Record/Feature</h5>

# %%
dataset_cl3.dropna(inplace=True)

dataset_cl3.isna().sum()
# Out:
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %% [markdown]
# <h5>Data Duplikat</h5>

# %%
dataset_duplicate = df3.copy()

dataset_duplicate.duplicated().sum()
# Out:
# 133

# %%
dataset_duplicate.drop_duplicates(inplace=True)

dataset_duplicate.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <h1>BAGIAN STANDARISASI SETELAH CLEANING DATA</h1>

# %%
standarisasi_dataset = dataset_cl3

# %%
ss = StandardScaler()
Scaled_data = ss.fit_transform(standarisasi_dataset[['budget', 'runtime', 'revenue', 'vote_count']])

# %%
print("Nilai Sebelum Standarisasi : ")
print("Standar Deviasi : ", np.std(standarisasi_dataset))
# Out:
# Nilai Sebelum Standarisasi :
# Standar Deviasi :  budget          5.367420e+07
# id              8.981173e+04
# popularity      4.819138e+01
# revenue         2.407905e+08
# runtime         1.937227e+01
# vote_average    9.701545e-01
# vote_count      1.791859e+03
# dtype: float64
# C:\Users\hpsam\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:3571: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %%
print("Nilai Setelah Standarisasi : ")
print("Standar Deviasi : ", np.std(Scaled_data))
# Out:
# Nilai Setelah Standarisasi :
# Standar Deviasi :  1.0

# %% [markdown]
# <h1>DATA ENCODING</h1>

# %%
dataset_ordinal = df3.copy()
dataset_one_hot = df3.copy()

# %% [markdown]
# <h5>ORDINAL</h5>

# %%
df3['Foot'].unique()
# Out:
# array(['Right', 'Left'], dtype=object)

# %%
encoder_ordinal =OrdinalEncoder()

#encoding kan
dataset_ordinal['Foot'] = encoder_ordinal.fit_transform(dataset_ordinal[['Foot']]).astype('int64')

#lihat
dataset_ordinal.head()
# Out:
#         PlayerName  Foot Position   AWR  DWR  OVR   PAC   SHO   PAS   DRI  \
# 0             Pelé     1      CAM  High  Med   98  95.0  96.0  93.0  96.0
# 1   Diego Maradona     0      CAM  High  Med   97  92.0  93.0  92.0  97.0
# 2          Ronaldo     1       ST   Med  Med   96  97.0  95.0  81.0  95.0
# 3  Zinedine Zidane     1      CAM   Med  Med   96  85.0  92.0  96.0  95.0
# 4   Diego Maradona     0      CAM  High  Med   95  88.0  91.0  90.0  95.0
#
#     DEF   PHY  SM  DIV  POS  HAN  REF  KIC  SPD
# 0  60.0  76.0   5  NaN  NaN  NaN  NaN  NaN  NaN
# 1  40.0  76.0   5  NaN  NaN  NaN  NaN  NaN  NaN
# 2  45.0  76.0   5  NaN  NaN  NaN  NaN  NaN  NaN
# 3  75.0  86.0   5  NaN  NaN  NaN  NaN  NaN  NaN
# 4  42.0  75.0   5  NaN  NaN  NaN  NaN  NaN  NaN

# %%
dataset_ordinal['Foot'].unique()
# Out:
# array([1, 0], dtype=int64)

# %% [markdown]
# <h5>ONE-HOT</h5>

# %%
temp_dataset = pd.get_dummies(dataset_one_hot[['Foot']])

temp_dataset = pd.DataFrame(temp_dataset)

dataset_one_hot.drop('Foot', axis=1, inplace=True)

dataset_one_hot = dataset_one_hot.join(temp_dataset)
dataset_one_hot.head(5)
# Out:
#         PlayerName Position   AWR  DWR  OVR   PAC   SHO   PAS   DRI   DEF  \
# 0             Pelé      CAM  High  Med   98  95.0  96.0  93.0  96.0  60.0
# 1   Diego Maradona      CAM  High  Med   97  92.0  93.0  92.0  97.0  40.0
# 2          Ronaldo       ST   Med  Med   96  97.0  95.0  81.0  95.0  45.0
# 3  Zinedine Zidane      CAM   Med  Med   96  85.0  92.0  96.0  95.0  75.0
# 4   Diego Maradona      CAM  High  Med   95  88.0  91.0  90.0  95.0  42.0
#
#     PHY  SM  DIV  POS  HAN  REF  KIC  SPD  Foot_Left  Foot_Right
# 0  76.0   5  NaN  NaN  NaN  NaN  NaN  NaN          0           1
# 1  76.0   5  NaN  NaN  NaN  NaN  NaN  NaN          1           0
# 2  76.0   5  NaN  NaN  NaN  NaN  NaN  NaN          0           1
# 3  86.0   5  NaN  NaN  NaN  NaN  NaN  NaN          0           1
# 4  75.0   5  NaN  NaN  NaN  NaN  NaN  NaN          1           0
